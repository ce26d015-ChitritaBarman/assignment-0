# %%
n=42
f=3.14
s="Hello world"
li=[1, 2, 3]
d={'key':'value'}
bool=True

# %%
a=10
b=3
print("a+b=",a+b)#addition
print("a%b=",a%b)#Modulus
print("a**b=",a**b)#Exponentiation
# Out:
# a+b= 13
# a%b= 1
# a**b= 1000

# %%
#declare list
L=[1, "a", "string",1+4]
print("Original list:",L)
#Adding element in list
L.append(1000)#adds 1000 at the end
print("After adding an element:", L)
#Deleting last element
L.pop()
print("After deleting the last element:",L)
# Out:
# Original list: [1, 'a', 'string', 5]
# After adding an element: [1, 'a', 'string', 5, 1000]
# After deleting the last element: [1, 'a', 'string', 5]

# %%
#importing the math module
import math
# using sqare root function
num=25
print("Square root of number is:", math.sqrt(num))
# using pi constant
num=25
print("the value of pie is:", math.pi)
# Out:
# Square root of number is: 5.0
# the value of pie is: 3.141592653589793

# %%
def add(x,y):
    return(x+y)
def sub(x,y):
    return(x-y)
def mul(x,y):
    return(x*y)
#input
x=10
y=3
#print result
print("Addition=", add(x,y))
print("Subtraction=", sub(x,y))
print("Multiplication=", mul(x,y))
# Out:
# Addition= 13
# Subtraction= 7
# Multiplication= 30

# %%
i=25
#checking if 1 is equal to 10
if i==10:
    print("i is equal to 10")
elif i==25:
    print("i is equal to 25")
# if none of the above
else:
    print("i is not 10, 15")
# Out:
# i is equal to 25

# %%
import numpy as np
import matplotlib.pyplot as plt
#generate x value
x=np.linspace(0, 2*np.pi, 100)
#create empty list
y=[]
#calculate sinx using a for loop
for i in x:
    y.append(np.sin(i))
plt.plot(x,y)
plt.show()
